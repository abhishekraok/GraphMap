# %% [markdown]
# # Zooming
#
# Here we will see how we can zoom into the created image.
# We can zoom into any quadrant using quadkeys.
#
# For this we will use sample graph called fruits node.

# %%
# %pylab inline
import sys
import os
sys.path.insert(0,'..')
import graphmap
from graphmap.graphmap_main import GraphMap
from graphmap.memory_persistence import MemoryPersistence
fruits_node_link = graphmap.samples.get_fruits_node_link()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
G = GraphMap(MemoryPersistence())
plt.imshow(G.get_image_at_quad_key(fruits_node_link, 256, '').value)
# Out:
# ('Loading node ', 'fruits', ' from file ', 'https://artmapstore.blob.core.windows.net/firstnodes/fruits.tsv')
# ('Getting contents from ', 'https://artmapstore.blob.core.windows.net/firstnodes/fruits.tsv')

# %%
plt.imshow(G.get_image_at_quad_key(fruits_node_link, 256, '0').value)

# %%
plt.imshow(G.get_image_at_quad_key(fruits_node_link, 256, '00').value)

# %%
plt.imshow(G.get_image_at_quad_key(fruits_node_link, 256, '003').value)
